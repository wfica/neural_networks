# %% [markdown]
# # Assignment 4
#
# **Submission deadline: last lab session before or on Wednesday, 22.11.17**
#
# **Edit (21.11.17): the problems 7 and 8 are due on Wednesday, 29.11.17. Please submit them via email, and remind the instrictor to grade them during the next lab session**
#
# **Points: 11 + 4 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %% [markdown]
# # Starter code: network for Irises in Pytorch
#
#
# In the following cells a feedforward neural network has been implemented with the aid of PyTorch and its autograd mechanism. Please study the code - many network implementations follow a similar pattern.
#
# The provided network trains to nearly 100% accuracy on Iris using Batch Gradient Descent.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch.autograd import Variable


class Layer(object):
    
    def train_mode(self):
        """Put layer into training mode.
        """
        self.training_mode = True
        pass
    
    def eval_mode(self):
        """Put layer into evalation mode.
        """
        self.training_mode = False
        pass
    
    @property
    def parameters(self):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out):
        self.W = Variable(torch.FloatTensor(num_in, num_out),
                          requires_grad=True)
        self.W.name = 'W'
        self.b = Variable(torch.FloatTensor(1, num_out),
                          requires_grad=True)
        self.b.name = 'b'
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    def forward(self, x):
        return x.mm(self.W) + self.b

    
class TanhLayer(Layer):
    def forward(self, x):
        return F.tanh(x)

    
class  ReLULayer(Layer):
    def forward(self, x):
        return F.relu(x)


class SoftMaxLayer(Layer):
    def forward(self, x):
        return F.softmax(x)
    
class DropOutLayer(Layer):
    def forward(self, x):
        return F.alpha_dropout(x, p= 0.25,  training=self.training_mode)
    
class SBNLayer(Layer):
    def __init__(self, num_in):
        self.W = Variable(torch.FloatTensor(num_in),
                          requires_grad=True)
        self.W.name = 'W'
        self.b = Variable(torch.FloatTensor(num_in),
                          requires_grad=True)
        self.b.name = 'b'
    
    @property
    def parameters(self):
        return [self.W, self.b]
    def forward(self, x):
        mi = torch.mean(x)
        sigma_2 = torch.std(x)
        x = (x - mi) / sigma_2
        return x * self.W + self.b

# %%
t = torch.FloatTensor([1,2,3])
q = torch.FloatTensor([4,5,6])

# %%
t * q + b
# Out:
#   4
#  10
#  18
# [torch.FloatTensor of size 3]

# %%
class FeedforwardNet(object):
    def __init__(self, layers):
        self.layers = layers

    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params

    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP.data = newP.data
    
    def train_mode(self):
        for layer in self.layers:
            layer.train_mode()
    
    def eval_mode(self):
        for layer in self.layers:
            layer.eval_mode()    
    
    def forward(self, x):
        for layer in self.layers:
            x = layer.forward(x)
        return x
    
    def loss(self, outputs, targets):
        return torch.mean(-torch.log(torch.gather(
            outputs, 1, targets.unsqueeze(1))))

# %%
from sklearn import datasets
import torchvision


iris = datasets.load_iris()
IrisX = iris.data.astype(np.float32)
IrisX = (IrisX - IrisX.mean(axis=0, keepdims=True)) / IrisX.std(axis=0, keepdims=True)
IrisY = iris.target

def GD(model, x, y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """Simple batch gradient descent"""
    try:
        old_loss = np.inf
        x = Variable(torch.from_numpy(x), requires_grad=False)
        y = Variable(torch.from_numpy(y.astype(np.int64)), requires_grad=False)
        model.train_mode()
        for i in xrange(max_iters):
            outputs = model.forward(x)
            loss = model.loss(outputs, y)

            loss.backward()
            for p in model.parameters:
                p.data -= p.grad.data * alpha
                # Zero gradients for the next iteration
                p.grad.data.zero_()

            loss = loss.data[0]
            if old_loss < loss:
                print "Iter: %d, loss increased!" % (i,)
            if (old_loss - loss) < tolerance:
                print "Tolerance level reached. Exiting."
                break
            if i % 1000 == 0:
                _, predictions = outputs.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / outputs.size(0)
                print "Iteration {0: >6} | loss {1: >5.2f} | err rate  {2: >5.2f}%" \
                      .format(i, loss, err_rate)
            old_loss = loss
    except KeyboardInterrupt:
        pass

# %%
model = FeedforwardNet(
    [AffineLayer(4, 10),
     TanhLayer(),
     AffineLayer(10, 3),
     SoftMaxLayer(),
    ])

# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        # p.data.normal_(0, 0.05)
        p.data.uniform_(-0.1, 0.1)
    elif p.name == 'b':
        p.data.zero_()
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# Train
GD(model, IrisX, IrisY, alpha=1e-1, tolerance=1e-7)
# Out:
# Iteration      0 | loss  1.09 | err rate  44.67%
# Iteration   1000 | loss  0.05 | err rate   2.00%
# Iteration   2000 | loss  0.04 | err rate   2.00%
# Iteration   3000 | loss  0.04 | err rate   1.33%
# Iteration   4000 | loss  0.04 | err rate   1.33%
# Iteration   5000 | loss  0.04 | err rate   1.33%
# Iteration   6000 | loss  0.04 | err rate   1.33%
# Iteration   7000 | loss  0.04 | err rate   1.33%
# Iteration   8000 | loss  0.04 | err rate   1.33%
# Iteration   9000 | loss  0.04 | err rate   1.33%
# Iteration  10000 | loss  0.04 | err rate   1.33%
# Iteration  11000 | loss  0.04 | err rate   1.33%
# Iteration  12000 | loss  0.04 | err rate   1.33%
# Iteration  13000 | loss  0.04 | err rate   1.33%
# Iteration  14000 | loss  0.04 | err rate   1.33%
# Iteration  15000 | loss  0.04 | err rate   1.33%
# Iteration  16000 | loss  0.04 | err rate   1.33%
# Iteration  17000 | loss  0.04 | err rate   1.33%
# Iteration  18000 | loss  0.04 | err rate   1.33%
# Iteration  19000 | loss  0.03 | err rate   1.33%
# Iteration  20000 | loss  0.03 | err rate   1.33%
# Iteration  21000 | loss  0.03 | err rate   1.33%
# Iteration  22000 | loss  0.03 | err rate   1.33%
# Iteration  23000 | loss  0.03 | err rate   1.33%
# Iteration  24000 | loss  0.03 | err rate   1.33%
# Iteration  25000 | loss  0.03 | err rate   1.33%
# Iteration  26000 | loss  0.03 | err rate   1.33%
# Iteration  27000 | loss  0.03 | err rate   1.33%
# Iteration  28000 | loss  0.03 | err rate   1.33%
# Iteration  29000 | loss  0.03 | err rate   1.33%
# Iteration  30000 | loss  0.03 | err rate   0.67%
# Iteration  31000 | loss  0.02 | err rate   0.67%
# Iteration  32000 | loss  0.02 | err rate   0.67%
# Iteration  33000 | loss  0.02 | err rate   0.67%
# Iteration  34000 | loss  0.02 | err rate   0.67%
# Iteration  35000 | loss  0.01 | err rate   0.67%
# Iteration  36000 | loss  0.01 | err rate   0.67%
# Iteration  37000 | loss  0.01 | err rate   0.00%
# Iteration  38000 | loss  0.01 | err rate   0.00%
# Iteration  39000 | loss  0.01 | err rate   0.00%
# Iteration  40000 | loss  0.01 | err rate   0.00%
# Iteration  41000 | loss  0.01 | err rate   0.00%
# Iteration  42000 | loss  0.01 | err rate   0.00%
# Iteration  43000 | loss  0.01 | err rate   0.00%
# Iteration  44000 | loss  0.01 | err rate   0.00%
# Iteration  45000 | loss  0.00 | err rate   0.00%
# Iteration  46000 | loss  0.00 | err rate   0.00%
# Iteration  47000 | loss  0.00 | err rate   0.00%
# Iteration  48000 | loss  0.00 | err rate   0.00%
# Iteration  49000 | loss  0.00 | err rate   0.00%
# Iteration  50000 | loss  0.00 | err rate   0.00%
# Iteration  51000 | loss  0.00 | err rate   0.00%
# Iteration  52000 | loss  0.00 | err rate   0.00%
# Iteration  53000 | loss  0.00 | err rate   0.00%
# Iteration  54000 | loss  0.00 | err rate   0.00%
# Iteration  55000 | loss  0.00 | err rate   0.00%
# Iteration  56000 | loss  0.00 | err rate   0.00%
# Tolerance level reached. Exiting.

# %% [markdown]
# # Starter code for MNIST and SGD scaffolding

# %%
import torch
import os
import torchvision


batch_size = 128
data_path = os.environ.get('PYTORCH_DATA_PATH', '../data')

transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.1307,), (0.3081,)),
    ])

_test = torchvision.datasets.MNIST(
    data_path, train=False, download=True, transform=transform)

# Load training data, split into train and valid sets
_train = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_train.train_data = _train.train_data[:50000]
_train.train_labels = _train.train_labels[:50000]

_valid = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_valid.train_data = _valid.train_data[50000:]
_valid.train_labels = _valid.train_labels[50000:]

mnist_loaders = {
    'train': torch.utils.data.DataLoader(
        _train, batch_size=batch_size, shuffle=True),
    'valid': torch.utils.data.DataLoader(
        _valid, batch_size=batch_size, shuffle=False),
    'test': torch.utils.data.DataLoader(
        _test, batch_size=batch_size, shuffle=False)}

# %%
torch.zeros(torch.FloatTensor([[1,2,3],[4,5,6]]).size())
# Out:
#  0  0  0
#  0  0  0
# [torch.FloatTensor of size 2x3]

# %%
def compute_error_rate(model, data_loader, cuda=False):
    model.eval_mode()
    num_errs = 0.0
    num_examples = 0
    for x, y in data_loader:
        if cuda:
            x = x.cuda()
            y = y.cuda()
        x = Variable(x.view(x.size(0), -1), volatile=True)
        y = Variable(y, volatile=True)
        outputs = model.forward(x)
        _, predictions = outputs.data.max(dim=1)
        num_errs += (predictions != y.data).sum()
        num_examples += x.size(0)
    return 100.0 * num_errs / num_examples

def SGD(model, data_loaders, alpha=1e-4, num_epochs=1, patience_expansion=1.5,
        log_every=100, cuda=False, learning_rate_decay = 1., momentum_rho = 0.95 , 
        theta_lambda= 0.00001, no_dropout = True, running_average = 0.8, poylak=False):
    if cuda:
        for p in model.parameters:
            p.data = p.data.cuda()

    # Initialize momentum variables
    if cuda:
        velocities = [torch.zeros(p.size()).cuda() for p in model.parameters]
    else:
        velocities = [torch.zeros(p.size()) for p in model.parameters]
    alpha0 = alpha + 0.
    average_params = [torch.zeros(p.size()) for p in model.parameters]
    iter_ = 0
    epoch = 0
    limit = 1.
    best_params = None
    best_val_err = np.inf
    history = {'train_losses': [], 'train_errs': [], 'val_errs': []}
    print('Training the model!')
    print('Interrupt at any time to evaluate the best validation model so far.')
    try:
        while epoch < num_epochs:
            model.train_mode()
            epoch += 1
            #if iter_ % 10000 == 0:
            #    alpha0 /= 2.
            
            for x, y in data_loaders['train']:
                if cuda:
                    x = x.cuda()
                    y = y.cuda()
                iter_ += 1
                x = Variable(x.view(x.size(0), -1), requires_grad=False)
                y = Variable(y, requires_grad=False)
                
                out = model.forward(x)
                loss = model.loss(out, y)
                loss.backward()
                _, predictions = out.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / out.size(0)

                history['train_losses'].append(loss.data[0])
                history['train_errs'].append(err_rate)

                for i, (p, v) in enumerate(zip(model.parameters, velocities)):
                    # weight decay addition to gradients 
                    if p.name == 'W':
                        p.grad.data += theta_lambda * p.data
                        
                    # Update learning rate
                    alpha = alpha0/ (1. + learning_rate_decay * epoch )

                    # TODO: Set the momentum constant                   
                    # velocity update in momentum
                    old_v = v
                    v = momentum_rho * v - alpha * p.grad.data
                    
                    # Nesterov momentum rule (http://cs231n.stanford.edu/slides/2017/cs231n_2017_lecture7.pdf)
                    p.data += -momentum_rho *  old_v + (1. + momentum_rho) * v
                    velocities[i] = v
                   #! p.data -= alpha * p.grad.data
                    # Zero gradients for the next iteration
                    p.grad.data.zero_()

                if iter_ % log_every == 0:
                    print "Minibatch {0: >6}  | loss {1: >5.2f} | err rate {2: >5.2f}%" \
                          .format(iter_, loss.data[0], err_rate)
            
            val_err_rate = compute_error_rate(model, data_loaders['valid'], cuda)
            history['val_errs'].append((iter_, val_err_rate))
            
            if val_err_rate < best_val_err:
                # Adjust num of epochs
                num_epochs = int(np.maximum(num_epochs, epoch * patience_expansion + 1))
                best_epoch = epoch
                best_val_err = val_err_rate
                best_params = [p.clone().cpu() for p in model.parameters]
                new_params = []
                for p_a, p_current in zip(best_params, average_params):
                    new_params.append(p_a.data * running_average + (1. - running_average) * p_current)
                average_params = new_params
            elif no_dropout and iter_ > 2000 * limit:
                alpha0 = alpha0 / 2. 
                limit = limit + 1.
            m = "After epoch {0: >2} | valid err rate: {1: >5.2f}% | doing {2: >3} epochs" \
                .format(epoch, val_err_rate, num_epochs)
            print '{0}\n{1}\n{0}'.format('-' * len(m), m)

    except KeyboardInterrupt:
        pass
    if best_params is not None:
        #print "\nLoading best params on validation set (epoch %d)\n" %(best_epoch)
        #print(best_params[0])
        #print('ala', average_params)
        if poylak: 
            model.parameters = [Variable(p) for p in average_params]
        else:
            model.parameters = best_params
    plot_history(history)

def plot_history(history):
    figsize(16, 4)
    subplot(1,2,1)
    train_loss = np.array(history['train_losses'])
    semilogy(np.arange(train_loss.shape[0]), train_loss, label='batch train loss')
    legend()
        
    subplot(1,2,2)
    train_errs = np.array(history['train_errs'])
    plot(np.arange(train_errs.shape[0]), train_errs, label='batch train error rate')
    val_errs = np.array(history['val_errs'])
    plot(val_errs[:,0], val_errs[:,1], label='validation error rate', color='r')
    ylim(0,20)
    legend()

# %%
t =torch.FloatTensor([1,2,3])
t
# Out:
#  1
#  2
#  3
# [torch.FloatTensor of size 3]

# %%
Variable(t)
# Out:
# Variable containing:
#  1
#  2
#  3
# [torch.FloatTensor of size 3]

# %% [markdown]
# # Problem 1: Stochastic Gradient Descent [3p]
# Implement the following additions to the SGD code provided above:
#   1. **[1p]** momentum
#   2. **[1p]** learning rate schedule
#   3. **[1p]** weight decay, in which we additionally minimize for each weight matrix (but typically not the bias) the sum of its elements squared. One way to implement it is to use function `model.parameters` and select all parameters whose names are "`W`" and not "`b`".

# %% [markdown]
# # Problem 2: Tuning the Network for MNIST [4p]
#
# Tune the following network to reach **validation error rate below 1.9%**.
# This should result in a **test error rate below 2%**. To
# tune the network you will need to:
# 1. Choose the number of layers (more than 1, less than 5);
# 2. Choose the number of neurons in each layer (more than 100,
#     less than 5000);
# 3. Pick proper weight initialization;
# 4. Pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches);
# 5. Pick a momentum constant (probably a constant one will be OK).

# %%
model = FeedforwardNet([
        AffineLayer(784,380),
        TanhLayer(),
        AffineLayer(380,100),
        TanhLayer(),
        AffineLayer(100,50),
        TanhLayer(),
        AffineLayer(50,10),
        SoftMaxLayer()
        ])

# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        p.data.normal_(0, 0.05)
        #p.data.uniform_(-0.1, 0.1)
    elif p.name == 'b':
        p.data.zero_()
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# On lab computers you can set cuda=True !
SGD(model, mnist_loaders, alpha=0.1, cuda=True)

print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.33 | err rate  7.81%
# Minibatch    200  | loss  0.12 | err rate  4.69%
# Minibatch    300  | loss  0.18 | err rate  5.47%
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  3.89% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    400  | loss  0.16 | err rate  6.25%
# Minibatch    500  | loss  0.11 | err rate  3.12%
# Minibatch    600  | loss  0.06 | err rate  2.34%
# Minibatch    700  | loss  0.07 | err rate  2.34%
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  2.72% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.15 | err rate  3.91%
# Minibatch    900  | loss  0.10 | err rate  2.34%
# Minibatch   1000  | loss  0.06 | err rate  1.56%
# Minibatch   1100  | loss  0.03 | err rate  1.56%
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  2.39% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   1200  | loss  0.01 | err rate  0.00%
# Minibatch   1300  | loss  0.04 | err rate  0.78%
# Minibatch   1400  | loss  0.01 | err rate  0.00%
# Minibatch   1500  | loss  0.06 | err rate  1.56%
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  2.25% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.02 | err rate  0.78%
# Minibatch   1700  | loss  0.01 | err rate  0.00%
# Minibatch   1800  | loss  0.01 | err rate  0.00%
# Minibatch   1900  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  2.16% | doing   8 epochs
# ----------------------------------------------------------
# Minibatch   2000  | loss  0.01 | err rate  0.00%
# Minibatch   2100  | loss  0.00 | err rate  0.00%
# Minibatch   2200  | loss  0.00 | err rate  0.00%
# Minibatch   2300  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  1.97% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.00 | err rate  0.00%
# Minibatch   2500  | loss  0.00 | err rate  0.00%
# Minibatch   2600  | loss  0.00 | err rate  0.00%
# Minibatch   2700  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  1.95% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   2800  | loss  0.00 | err rate  0.00%
# Minibatch   2900  | loss  0.00 | err rate  0.00%
# Minibatch   3000  | loss  0.00 | err rate  0.00%
# Minibatch   3100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  1.85% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.00 | err rate  0.00%
# Minibatch   3300  | loss  0.00 | err rate  0.00%
# Minibatch   3400  | loss  0.00 | err rate  0.00%
# Minibatch   3500  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  1.89% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3600  | loss  0.00 | err rate  0.00%
# Minibatch   3700  | loss  0.00 | err rate  0.00%
# Minibatch   3800  | loss  0.00 | err rate  0.00%
# Minibatch   3900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  1.87% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.00 | err rate  0.00%
# Minibatch   4100  | loss  0.00 | err rate  0.00%
# Minibatch   4200  | loss  0.00 | err rate  0.00%
# Minibatch   4300  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  1.89% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   4400  | loss  0.00 | err rate  0.00%
# Minibatch   4500  | loss  0.00 | err rate  0.00%
# Minibatch   4600  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  1.88% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.00 | err rate  0.00%
# Minibatch   4800  | loss  0.00 | err rate  0.00%
# Minibatch   4900  | loss  0.00 | err rate  0.00%
# Minibatch   5000  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  1.87% | doing  13 epochs
# ----------------------------------------------------------
#
# Loading best params on validation set (epoch 8)
#
# Test error rate: 2.01%

# %% [markdown]
# # Problem 3: Dropout [2p]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout. The best
# results with dropout are below 1%!
#
# Remember to turn off dropout during testing, using `model.train_mode()` and `model.eval_mode()`!
#
# Hint: Use [torch.nn.functional.dropout](http://pytorch.org/docs/master/nn.html#torch.nn.functional.dropout).
#
# Details: http://arxiv.org/pdf/1207.0580.pdf.

# %%
model = FeedforwardNet([
        AffineLayer(784,700),
        ReLULayer(),
        AffineLayer(700,500),
        ReLULayer(),
        AffineLayer(500,300),
        ReLULayer(),
        DropOutLayer(),
        AffineLayer(300,10),
        SoftMaxLayer()
        ])
model.train_mode()
# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        p.data.normal_(0, 0.04)
        #p.data.uniform_(-0.1, 0.1)
    elif p.name == 'b':
        p.data.zero_()
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# On lab computers you can set cuda=True !
SGD(model, mnist_loaders, alpha=0.1, cuda=True, no_dropout=False)

model.eval_mode()
print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.28 | err rate  7.81%
# Minibatch    200  | loss  0.43 | err rate  9.38%
# Minibatch    300  | loss  0.20 | err rate  5.47%
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  3.52% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    400  | loss  0.29 | err rate  6.25%
# Minibatch    500  | loss  0.12 | err rate  3.12%
# Minibatch    600  | loss  0.10 | err rate  3.12%
# Minibatch    700  | loss  0.19 | err rate  3.91%
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  2.94% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.09 | err rate  2.34%
# Minibatch    900  | loss  0.06 | err rate  1.56%
# Minibatch   1000  | loss  0.08 | err rate  0.78%
# Minibatch   1100  | loss  0.07 | err rate  0.78%
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  2.17% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   1200  | loss  0.02 | err rate  0.78%
# Minibatch   1300  | loss  0.01 | err rate  0.00%
# Minibatch   1400  | loss  0.02 | err rate  0.00%
# Minibatch   1500  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  2.06% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.00 | err rate  0.00%
# Minibatch   1700  | loss  0.00 | err rate  0.00%
# Minibatch   1800  | loss  0.05 | err rate  1.56%
# Minibatch   1900  | loss  0.02 | err rate  1.56%
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  1.88% | doing   8 epochs
# ----------------------------------------------------------
# Minibatch   2000  | loss  0.00 | err rate  0.00%
# Minibatch   2100  | loss  0.03 | err rate  0.78%
# Minibatch   2200  | loss  0.08 | err rate  0.78%
# Minibatch   2300  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  1.81% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.00 | err rate  0.00%
# Minibatch   2500  | loss  0.00 | err rate  0.00%
# Minibatch   2600  | loss  0.00 | err rate  0.00%
# Minibatch   2700  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  1.69% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   2800  | loss  0.00 | err rate  0.00%
# Minibatch   2900  | loss  0.00 | err rate  0.00%
# Minibatch   3000  | loss  0.00 | err rate  0.00%
# Minibatch   3100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  1.63% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.00 | err rate  0.00%
# Minibatch   3300  | loss  0.00 | err rate  0.00%
# Minibatch   3400  | loss  0.02 | err rate  0.78%
# Minibatch   3500  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  1.63% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3600  | loss  0.00 | err rate  0.00%
# Minibatch   3700  | loss  0.00 | err rate  0.00%
# Minibatch   3800  | loss  0.00 | err rate  0.00%
# Minibatch   3900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  1.62% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.01 | err rate  0.00%
# Minibatch   4100  | loss  0.00 | err rate  0.00%
# Minibatch   4200  | loss  0.01 | err rate  0.78%
# Minibatch   4300  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  1.66% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   4400  | loss  0.00 | err rate  0.00%
# Minibatch   4500  | loss  0.00 | err rate  0.00%
# Minibatch   4600  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  1.60% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.00 | err rate  0.00%
# Minibatch   4800  | loss  0.00 | err rate  0.00%
# Minibatch   4900  | loss  0.00 | err rate  0.00%
# Minibatch   5000  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  1.67% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch   5100  | loss  0.00 | err rate  0.00%
# Minibatch   5200  | loss  0.00 | err rate  0.00%
# Minibatch   5300  | loss  0.00 | err rate  0.00%
# Minibatch   5400  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  1.60% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.00 | err rate  0.00%
# Minibatch   5600  | loss  0.00 | err rate  0.00%
# Minibatch   5700  | loss  0.00 | err rate  0.00%
# Minibatch   5800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  1.55% | doing  23 epochs
# ----------------------------------------------------------
# Minibatch   5900  | loss  0.00 | err rate  0.00%
# Minibatch   6000  | loss  0.00 | err rate  0.00%
# Minibatch   6100  | loss  0.00 | err rate  0.00%
# Minibatch   6200  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  1.57% | doing  23 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.00 | err rate  0.00%
# Minibatch   6400  | loss  0.00 | err rate  0.00%
# Minibatch   6500  | loss  0.00 | err rate  0.00%
# Minibatch   6600  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  1.52% | doing  26 epochs
# ----------------------------------------------------------
# Minibatch   6700  | loss  0.00 | err rate  0.00%
# Minibatch   6800  | loss  0.00 | err rate  0.00%
# Minibatch   6900  | loss  0.00 | err rate  0.00%
# Minibatch   7000  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  1.55% | doing  26 epochs
# ----------------------------------------------------------
# Minibatch   7100  | loss  0.00 | err rate  0.00%
# Minibatch   7200  | loss  0.00 | err rate  0.00%
# Minibatch   7300  | loss  0.00 | err rate  0.00%
# Minibatch   7400  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  1.64% | doing  26 epochs
# ----------------------------------------------------------
# Minibatch   7500  | loss  0.00 | err rate  0.00%
# Minibatch   7600  | loss  0.00 | err rate  0.00%
# Minibatch   7700  | loss  0.00 | err rate  0.00%
# Minibatch   7800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  1.49% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch   7900  | loss  0.00 | err rate  0.00%
# Minibatch   8000  | loss  0.00 | err rate  0.00%
# Minibatch   8100  | loss  0.00 | err rate  0.00%
# Minibatch   8200  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 21 | valid err rate:  1.51% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch   8300  | loss  0.00 | err rate  0.00%
# Minibatch   8400  | loss  0.00 | err rate  0.00%
# Minibatch   8500  | loss  0.00 | err rate  0.00%
# Minibatch   8600  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 22 | valid err rate:  1.54% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch   8700  | loss  0.00 | err rate  0.00%
# Minibatch   8800  | loss  0.00 | err rate  0.00%
# Minibatch   8900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 23 | valid err rate:  1.58% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch   9000  | loss  0.00 | err rate  0.00%
# Minibatch   9100  | loss  0.00 | err rate  0.00%
# Minibatch   9200  | loss  0.00 | err rate  0.00%
# Minibatch   9300  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 24 | valid err rate:  1.56% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch   9400  | loss  0.00 | err rate  0.00%
# Minibatch   9500  | loss  0.00 | err rate  0.00%
# Minibatch   9600  | loss  0.00 | err rate  0.00%
# Minibatch   9700  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 25 | valid err rate:  1.56% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch   9800  | loss  0.00 | err rate  0.00%
# Minibatch   9900  | loss  0.00 | err rate  0.00%
# Minibatch  10000  | loss  0.00 | err rate  0.00%
# Minibatch  10100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 26 | valid err rate:  1.59% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch  10200  | loss  0.00 | err rate  0.00%
# Minibatch  10300  | loss  0.00 | err rate  0.00%
# Minibatch  10400  | loss  0.00 | err rate  0.00%
# Minibatch  10500  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 27 | valid err rate:  1.55% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch  10600  | loss  0.00 | err rate  0.00%
# Minibatch  10700  | loss  0.00 | err rate  0.00%
# Minibatch  10800  | loss  0.00 | err rate  0.00%
# Minibatch  10900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 28 | valid err rate:  1.58% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch  11000  | loss  0.00 | err rate  0.00%
# Minibatch  11100  | loss  0.00 | err rate  0.00%
# Minibatch  11200  | loss  0.00 | err rate  0.00%
# Minibatch  11300  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 29 | valid err rate:  1.57% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch  11400  | loss  0.00 | err rate  0.00%
# Minibatch  11500  | loss  0.00 | err rate  0.00%
# Minibatch  11600  | loss  0.00 | err rate  0.00%
# Minibatch  11700  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 30 | valid err rate:  1.60% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch  11800  | loss  0.00 | err rate  0.00%
# Minibatch  11900  | loss  0.01 | err rate  0.00%
# Minibatch  12000  | loss  0.00 | err rate  0.00%
# Minibatch  12100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 31 | valid err rate:  1.62% | doing  31 epochs
# ----------------------------------------------------------
#
# Loading best params on validation set (epoch 20)
#
# Test error rate: 1.52%

# %% [markdown]
# # Problem 4: Data Augmentation [1p]
#
# Apply data augmentation methods (e.g. rotations, noise, crops) when training networks on MNIST, to significantly reduce test error rate for your network. You can use functions from the [torchvision.transforms](http://pytorch.org/docs/master/torchvision/transforms.html) module.

# %%
def add_noise(img):
    img_numpy = img.numpy()
    mi = img_numpy.ravel().mean()
    sigma = img_numpy.ravel().std()
    noise = np.random.normal(mi/2, sigma/4, size=img_numpy.shape)
    img_numpy += noise
    return torch.from_numpy(img_numpy)

def shift_right(res, img, offset):
    res[0][offset:, :] = img[0][:-offset,:]
    return res
def shift_left(res, img, offset):
    res[0][:-offset, :] = img[0][offset:, :]
    return res
def shift_up(res, img, offset):
    res[0][:, offset:] = img[0][:,:-offset]
    return res
def shift_down(res, img, offset):
    res[0][:,:-offset] = img[0][:, offset:]
    return res


def shift_randomly(img):
    funcs = [shift_right, shift_left, shift_up, shift_down]
    img_numpy = img.numpy()
    res = np.zeros_like(img_numpy)
    f = funcs[np.random.randint(4)]
    res = f(res, img_numpy, 3)
    return torch.from_numpy(res)

# %%
import torch
import os
import torchvision


batch_size = 128
data_path = os.environ.get('PYTORCH_DATA_PATH', '../data')

transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.1307,), (0.3081,)),
    ])

_test = torchvision.datasets.MNIST(
    data_path, train=False, download=True, transform=transform)

_train = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_train.train_data = _train.train_data[:50000]
_train.train_labels = _train.train_labels[:50000]

_valid = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_valid.train_data = _valid.train_data[50000:]
_valid.train_labels = _valid.train_labels[50000:]

transform_noisy = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Lambda(add_noise),
     torchvision.transforms.Lambda(shift_randomly),
     torchvision.transforms.Normalize((0.1307,), (0.3081,)),
    ])


_train_noisy = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform_noisy)
_train_noisy.train_data = _train_noisy.train_data[:50000]
_train_noisy.train_labels = _train_noisy.train_labels[:50000]

_valid_noisy = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform_noisy)
_valid_noisy.train_data = _valid_noisy.train_data[50000:]
_valid_noisy.train_labels = _valid_noisy.train_labels[50000:]

mnist_loaders = {
    'train': torch.utils.data.DataLoader(
        torch.utils.data.ConcatDataset([_train, _train_noisy]), 
        batch_size=batch_size, shuffle=True),
    'valid': torch.utils.data.DataLoader(
        torch.utils.data.ConcatDataset([_valid, _valid_noisy]),
        batch_size=batch_size, shuffle=False),
    'test': torch.utils.data.DataLoader(
        _test, batch_size=batch_size, shuffle=False)}

# %%
model = FeedforwardNet([
        AffineLayer(784,700),
        ReLULayer(),
        AffineLayer(700,500),
        ReLULayer(),
        AffineLayer(500,300),
        ReLULayer(),
        DropOutLayer(),
        AffineLayer(300,10),
        SoftMaxLayer()
        ])
model.train_mode()
# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        x = min(0.04, np.sqrt(6.) / np.sqrt( p.data.size()[0] + p.data.size()[1] ))
        p.data.uniform_(-x, x)
    elif p.name == 'b':
        p.data.zero_()
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# On lab computers you can set cuda=True !
SGD(model, mnist_loaders, alpha=0.1, cuda=True, no_dropout=False)

model.eval_mode()
print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  1.03 | err rate 28.91%
# Minibatch    200  | loss  0.32 | err rate  9.38%
# Minibatch    300  | loss  0.27 | err rate  8.59%
# Minibatch    400  | loss  0.47 | err rate 15.62%
# Minibatch    500  | loss  0.34 | err rate 10.94%
# Minibatch    600  | loss  0.36 | err rate  9.38%
# Minibatch    700  | loss  0.31 | err rate  9.38%
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  5.55% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.31 | err rate  8.59%
# Minibatch    900  | loss  0.22 | err rate  6.25%
# Minibatch   1000  | loss  0.12 | err rate  3.12%
# Minibatch   1100  | loss  0.30 | err rate  7.81%
# Minibatch   1200  | loss  0.11 | err rate  3.12%
# Minibatch   1300  | loss  0.12 | err rate  4.69%
# Minibatch   1400  | loss  0.14 | err rate  3.91%
# Minibatch   1500  | loss  0.19 | err rate  7.81%
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  3.13% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.09 | err rate  3.91%
# Minibatch   1700  | loss  0.07 | err rate  3.91%
# Minibatch   1800  | loss  0.09 | err rate  3.12%
# Minibatch   1900  | loss  0.04 | err rate  0.78%
# Minibatch   2000  | loss  0.17 | err rate  4.69%
# Minibatch   2100  | loss  0.18 | err rate  3.91%
# Minibatch   2200  | loss  0.20 | err rate  4.69%
# Minibatch   2300  | loss  0.04 | err rate  1.56%
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  2.48% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.06 | err rate  0.78%
# Minibatch   2500  | loss  0.13 | err rate  3.91%
# Minibatch   2600  | loss  0.03 | err rate  0.78%
# Minibatch   2700  | loss  0.13 | err rate  3.12%
# Minibatch   2800  | loss  0.24 | err rate  2.34%
# Minibatch   2900  | loss  0.09 | err rate  3.12%
# Minibatch   3000  | loss  0.04 | err rate  0.78%
# Minibatch   3100  | loss  0.07 | err rate  2.34%
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  2.11% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.12 | err rate  3.91%
# Minibatch   3300  | loss  0.04 | err rate  0.78%
# Minibatch   3400  | loss  0.11 | err rate  1.56%
# Minibatch   3500  | loss  0.03 | err rate  0.78%
# Minibatch   3600  | loss  0.06 | err rate  2.34%
# Minibatch   3700  | loss  0.04 | err rate  0.78%
# Minibatch   3800  | loss  0.04 | err rate  1.56%
# Minibatch   3900  | loss  0.04 | err rate  1.56%
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  1.93% | doing   8 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.07 | err rate  2.34%
# Minibatch   4100  | loss  0.03 | err rate  0.78%
# Minibatch   4200  | loss  0.07 | err rate  1.56%
# Minibatch   4300  | loss  0.11 | err rate  3.91%
# Minibatch   4400  | loss  0.07 | err rate  1.56%
# Minibatch   4500  | loss  0.03 | err rate  0.78%
# Minibatch   4600  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  1.94% | doing   8 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.06 | err rate  2.34%
# Minibatch   4800  | loss  0.10 | err rate  3.12%
# Minibatch   4900  | loss  0.02 | err rate  0.78%
# Minibatch   5000  | loss  0.04 | err rate  1.56%
# Minibatch   5100  | loss  0.07 | err rate  1.56%
# Minibatch   5200  | loss  0.10 | err rate  2.34%
# Minibatch   5300  | loss  0.01 | err rate  0.78%
# Minibatch   5400  | loss  0.12 | err rate  1.56%
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  1.72% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.10 | err rate  2.34%
# Minibatch   5600  | loss  0.05 | err rate  0.78%
# Minibatch   5700  | loss  0.02 | err rate  0.78%
# Minibatch   5800  | loss  0.00 | err rate  0.00%
# Minibatch   5900  | loss  0.04 | err rate  0.78%
# Minibatch   6000  | loss  0.00 | err rate  0.00%
# Minibatch   6100  | loss  0.06 | err rate  1.56%
# Minibatch   6200  | loss  0.07 | err rate  1.56%
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  1.84% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.00 | err rate  0.00%
# Minibatch   6400  | loss  0.03 | err rate  0.78%
# Minibatch   6500  | loss  0.01 | err rate  0.78%
# Minibatch   6600  | loss  0.07 | err rate  1.56%
# Minibatch   6700  | loss  0.01 | err rate  0.00%
# Minibatch   6800  | loss  0.04 | err rate  0.78%
# Minibatch   6900  | loss  0.06 | err rate  0.78%
# Minibatch   7000  | loss  0.03 | err rate  0.78%
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  1.62% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   7100  | loss  0.01 | err rate  0.78%
# Minibatch   7200  | loss  0.01 | err rate  0.00%
# Minibatch   7300  | loss  0.04 | err rate  0.78%
# Minibatch   7400  | loss  0.11 | err rate  2.34%
# Minibatch   7500  | loss  0.04 | err rate  1.56%
# Minibatch   7600  | loss  0.01 | err rate  0.00%
# Minibatch   7700  | loss  0.02 | err rate  0.78%
# Minibatch   7800  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  1.65% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   7900  | loss  0.01 | err rate  0.00%
# Minibatch   8000  | loss  0.00 | err rate  0.00%
# Minibatch   8100  | loss  0.04 | err rate  0.78%
# Minibatch   8200  | loss  0.06 | err rate  1.56%
# Minibatch   8300  | loss  0.01 | err rate  0.00%
# Minibatch   8400  | loss  0.01 | err rate  0.78%
# Minibatch   8500  | loss  0.03 | err rate  0.78%
# Minibatch   8600  | loss  0.03 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  1.75% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   8700  | loss  0.03 | err rate  1.56%
# Minibatch   8800  | loss  0.02 | err rate  0.78%
# Minibatch   8900  | loss  0.00 | err rate  0.00%
# Minibatch   9000  | loss  0.05 | err rate  2.34%
# Minibatch   9100  | loss  0.02 | err rate  1.56%
# Minibatch   9200  | loss  0.01 | err rate  0.00%
# Minibatch   9300  | loss  0.03 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  1.68% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   9400  | loss  0.01 | err rate  0.00%
# Minibatch   9500  | loss  0.12 | err rate  2.34%
# Minibatch   9600  | loss  0.03 | err rate  0.78%
# Minibatch   9700  | loss  0.01 | err rate  0.78%
# Minibatch   9800  | loss  0.05 | err rate  1.56%
# Minibatch   9900  | loss  0.00 | err rate  0.00%
# Minibatch  10000  | loss  0.01 | err rate  0.00%
# Minibatch  10100  | loss  0.07 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  1.53% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch  10200  | loss  0.01 | err rate  0.00%
# Minibatch  10300  | loss  0.01 | err rate  0.00%
# Minibatch  10400  | loss  0.01 | err rate  0.00%
# Minibatch  10500  | loss  0.02 | err rate  0.78%
# Minibatch  10600  | loss  0.05 | err rate  1.56%
# Minibatch  10700  | loss  0.09 | err rate  2.34%
# Minibatch  10800  | loss  0.00 | err rate  0.00%
# Minibatch  10900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  1.57% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch  11000  | loss  0.02 | err rate  0.78%
# Minibatch  11100  | loss  0.00 | err rate  0.00%
# Minibatch  11200  | loss  0.00 | err rate  0.00%
# Minibatch  11300  | loss  0.00 | err rate  0.00%
# Minibatch  11400  | loss  0.00 | err rate  0.00%
# Minibatch  11500  | loss  0.04 | err rate  0.78%
# Minibatch  11600  | loss  0.00 | err rate  0.00%
# Minibatch  11700  | loss  0.09 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  1.51% | doing  23 epochs
# ----------------------------------------------------------
# Minibatch  11800  | loss  0.07 | err rate  0.78%
# Minibatch  11900  | loss  0.03 | err rate  0.78%
# Minibatch  12000  | loss  0.01 | err rate  0.78%
# Minibatch  12100  | loss  0.01 | err rate  0.00%
# Minibatch  12200  | loss  0.01 | err rate  0.00%
# Minibatch  12300  | loss  0.01 | err rate  0.78%
# Minibatch  12400  | loss  0.01 | err rate  0.78%
# Minibatch  12500  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  1.51% | doing  23 epochs
# ----------------------------------------------------------
# Minibatch  12600  | loss  0.01 | err rate  0.00%
# Minibatch  12700  | loss  0.02 | err rate  0.78%
# Minibatch  12800  | loss  0.05 | err rate  0.78%
# Minibatch  12900  | loss  0.06 | err rate  3.12%
# Minibatch  13000  | loss  0.00 | err rate  0.00%
# Minibatch  13100  | loss  0.04 | err rate  1.56%
# Minibatch  13200  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  1.50% | doing  26 epochs
# ----------------------------------------------------------
# Minibatch  13300  | loss  0.00 | err rate  0.00%
# Minibatch  13400  | loss  0.03 | err rate  0.78%
# Minibatch  13500  | loss  0.01 | err rate  0.00%
# Minibatch  13600  | loss  0.01 | err rate  0.00%
# Minibatch  13700  | loss  0.02 | err rate  0.78%
# Minibatch  13800  | loss  0.03 | err rate  1.56%
# Minibatch  13900  | loss  0.03 | err rate  0.78%
# Minibatch  14000  | loss  0.05 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  1.49% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  14100  | loss  0.02 | err rate  0.78%
# Minibatch  14200  | loss  0.02 | err rate  0.78%
# Minibatch  14300  | loss  0.03 | err rate  0.78%
# Minibatch  14400  | loss  0.00 | err rate  0.00%
# Minibatch  14500  | loss  0.04 | err rate  0.78%
# Minibatch  14600  | loss  0.00 | err rate  0.00%
# Minibatch  14700  | loss  0.01 | err rate  0.78%
# Minibatch  14800  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  1.50% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  14900  | loss  0.04 | err rate  1.56%
# Minibatch  15000  | loss  0.00 | err rate  0.00%
# Minibatch  15100  | loss  0.00 | err rate  0.00%
# Minibatch  15200  | loss  0.01 | err rate  0.78%
# Minibatch  15300  | loss  0.01 | err rate  0.00%
# Minibatch  15400  | loss  0.06 | err rate  0.78%
# Minibatch  15500  | loss  0.02 | err rate  0.78%
# Minibatch  15600  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  1.47% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch  15700  | loss  0.00 | err rate  0.00%
# Minibatch  15800  | loss  0.01 | err rate  0.00%
# Minibatch  15900  | loss  0.01 | err rate  0.00%
# Minibatch  16000  | loss  0.04 | err rate  0.78%
# Minibatch  16100  | loss  0.00 | err rate  0.00%
# Minibatch  16200  | loss  0.00 | err rate  0.00%
# Minibatch  16300  | loss  0.00 | err rate  0.00%
# Minibatch  16400  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 21 | valid err rate:  1.47% | doing  32 epochs
# ----------------------------------------------------------
# Minibatch  16500  | loss  0.00 | err rate  0.00%
# Minibatch  16600  | loss  0.01 | err rate  0.00%
# Minibatch  16700  | loss  0.01 | err rate  0.78%
# Minibatch  16800  | loss  0.00 | err rate  0.00%
# Minibatch  16900  | loss  0.01 | err rate  0.78%
# Minibatch  17000  | loss  0.00 | err rate  0.00%
# Minibatch  17100  | loss  0.00 | err rate  0.00%
# Minibatch  17200  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 22 | valid err rate:  1.45% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch  17300  | loss  0.00 | err rate  0.00%
# Minibatch  17400  | loss  0.01 | err rate  0.00%
# Minibatch  17500  | loss  0.05 | err rate  1.56%
# Minibatch  17600  | loss  0.02 | err rate  0.78%
# Minibatch  17700  | loss  0.05 | err rate  2.34%
# Minibatch  17800  | loss  0.02 | err rate  0.78%
# Minibatch  17900  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 23 | valid err rate:  1.45% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch  18000  | loss  0.02 | err rate  1.56%
# Minibatch  18100  | loss  0.00 | err rate  0.00%
# Minibatch  18200  | loss  0.00 | err rate  0.00%
# Minibatch  18300  | loss  0.04 | err rate  1.56%
# Minibatch  18400  | loss  0.00 | err rate  0.00%
# Minibatch  18500  | loss  0.00 | err rate  0.00%
# Minibatch  18600  | loss  0.00 | err rate  0.00%
# Minibatch  18700  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 24 | valid err rate:  1.41% | doing  37 epochs
# ----------------------------------------------------------
# Minibatch  18800  | loss  0.02 | err rate  0.78%
# Minibatch  18900  | loss  0.00 | err rate  0.00%
# Minibatch  19000  | loss  0.00 | err rate  0.00%
# Minibatch  19100  | loss  0.01 | err rate  0.00%
# Minibatch  19200  | loss  0.00 | err rate  0.00%
# Minibatch  19300  | loss  0.00 | err rate  0.00%
# Minibatch  19400  | loss  0.01 | err rate  0.00%
# Minibatch  19500  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 25 | valid err rate:  1.46% | doing  37 epochs
# ----------------------------------------------------------
# Minibatch  19600  | loss  0.01 | err rate  0.00%
# Minibatch  19700  | loss  0.04 | err rate  1.56%
# Minibatch  19800  | loss  0.00 | err rate  0.00%
# Minibatch  19900  | loss  0.01 | err rate  0.78%
# Minibatch  20000  | loss  0.00 | err rate  0.00%
# Minibatch  20100  | loss  0.01 | err rate  0.78%
# Minibatch  20200  | loss  0.00 | err rate  0.00%
# Minibatch  20300  | loss  0.03 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 26 | valid err rate:  1.42% | doing  37 epochs
# ----------------------------------------------------------
# Minibatch  20400  | loss  0.02 | err rate  0.78%
# Minibatch  20500  | loss  0.00 | err rate  0.00%
# Minibatch  20600  | loss  0.04 | err rate  0.78%
# Minibatch  20700  | loss  0.03 | err rate  1.56%
# Minibatch  20800  | loss  0.00 | err rate  0.00%
# Minibatch  20900  | loss  0.02 | err rate  0.78%
# Minibatch  21000  | loss  0.01 | err rate  0.00%
# Minibatch  21100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 27 | valid err rate:  1.41% | doing  37 epochs
# ----------------------------------------------------------
# Minibatch  21200  | loss  0.01 | err rate  0.00%
# Minibatch  21300  | loss  0.00 | err rate  0.00%
# Minibatch  21400  | loss  0.00 | err rate  0.00%
# Minibatch  21500  | loss  0.03 | err rate  0.78%
# Minibatch  21600  | loss  0.00 | err rate  0.00%
# Minibatch  21700  | loss  0.01 | err rate  0.00%
# Minibatch  21800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 28 | valid err rate:  1.49% | doing  37 epochs
# ----------------------------------------------------------
# Minibatch  21900  | loss  0.02 | err rate  0.78%
# Minibatch  22000  | loss  0.01 | err rate  0.78%
# Minibatch  22100  | loss  0.01 | err rate  0.78%
# Minibatch  22200  | loss  0.00 | err rate  0.00%
# Minibatch  22300  | loss  0.00 | err rate  0.00%
# Minibatch  22400  | loss  0.01 | err rate  0.78%
# Minibatch  22500  | loss  0.00 | err rate  0.00%
# Minibatch  22600  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 29 | valid err rate:  1.36% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  22700  | loss  0.00 | err rate  0.00%
# Minibatch  22800  | loss  0.01 | err rate  0.78%
# Minibatch  22900  | loss  0.01 | err rate  0.00%
# Minibatch  23000  | loss  0.00 | err rate  0.00%
# Minibatch  23100  | loss  0.00 | err rate  0.00%
# Minibatch  23200  | loss  0.01 | err rate  0.00%
# Minibatch  23300  | loss  0.00 | err rate  0.00%
# Minibatch  23400  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 30 | valid err rate:  1.47% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  23500  | loss  0.00 | err rate  0.00%
# Minibatch  23600  | loss  0.01 | err rate  0.78%
# Minibatch  23700  | loss  0.00 | err rate  0.00%
# Minibatch  23800  | loss  0.00 | err rate  0.00%
# Minibatch  23900  | loss  0.04 | err rate  0.78%
# Minibatch  24000  | loss  0.01 | err rate  0.00%
# Minibatch  24100  | loss  0.01 | err rate  0.78%
# Minibatch  24200  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 31 | valid err rate:  1.38% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  24300  | loss  0.01 | err rate  0.00%
# Minibatch  24400  | loss  0.00 | err rate  0.00%
# Minibatch  24500  | loss  0.00 | err rate  0.00%
# Minibatch  24600  | loss  0.00 | err rate  0.00%
# Minibatch  24700  | loss  0.00 | err rate  0.00%
# Minibatch  24800  | loss  0.01 | err rate  0.00%
# Minibatch  24900  | loss  0.02 | err rate  0.78%
# Minibatch  25000  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 32 | valid err rate:  1.47% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  25100  | loss  0.01 | err rate  0.78%
# Minibatch  25200  | loss  0.01 | err rate  0.00%
# Minibatch  25300  | loss  0.01 | err rate  0.78%
# Minibatch  25400  | loss  0.00 | err rate  0.00%
# Minibatch  25500  | loss  0.00 | err rate  0.00%
# Minibatch  25600  | loss  0.00 | err rate  0.00%
# Minibatch  25700  | loss  0.01 | err rate  0.78%
# Minibatch  25800  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 33 | valid err rate:  1.42% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  25900  | loss  0.02 | err rate  0.78%
# Minibatch  26000  | loss  0.00 | err rate  0.00%
# Minibatch  26100  | loss  0.00 | err rate  0.00%
# Minibatch  26200  | loss  0.00 | err rate  0.00%
# Minibatch  26300  | loss  0.00 | err rate  0.00%
# Minibatch  26400  | loss  0.04 | err rate  0.78%
# Minibatch  26500  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 34 | valid err rate:  1.47% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  26600  | loss  0.01 | err rate  0.78%
# Minibatch  26700  | loss  0.06 | err rate  2.34%
# Minibatch  26800  | loss  0.00 | err rate  0.00%
# Minibatch  26900  | loss  0.04 | err rate  2.34%
# Minibatch  27000  | loss  0.00 | err rate  0.00%
# Minibatch  27100  | loss  0.00 | err rate  0.00%
# Minibatch  27200  | loss  0.00 | err rate  0.00%
# Minibatch  27300  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 35 | valid err rate:  1.32% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  27400  | loss  0.00 | err rate  0.00%
# Minibatch  27500  | loss  0.02 | err rate  1.56%
# Minibatch  27600  | loss  0.00 | err rate  0.00%
# Minibatch  27700  | loss  0.00 | err rate  0.00%
# Minibatch  27800  | loss  0.00 | err rate  0.00%
# Minibatch  27900  | loss  0.00 | err rate  0.00%
# Minibatch  28000  | loss  0.00 | err rate  0.00%
# Minibatch  28100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 36 | valid err rate:  1.38% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  28200  | loss  0.03 | err rate  1.56%
# Minibatch  28300  | loss  0.00 | err rate  0.00%
# Minibatch  28400  | loss  0.01 | err rate  0.00%
# Minibatch  28500  | loss  0.00 | err rate  0.00%
# Minibatch  28600  | loss  0.00 | err rate  0.00%
# Minibatch  28700  | loss  0.02 | err rate  0.78%
# Minibatch  28800  | loss  0.00 | err rate  0.00%
# Minibatch  28900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 37 | valid err rate:  1.44% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  29000  | loss  0.00 | err rate  0.00%
# Minibatch  29100  | loss  0.00 | err rate  0.00%
# Minibatch  29200  | loss  0.00 | err rate  0.00%
# Minibatch  29300  | loss  0.00 | err rate  0.00%
# Minibatch  29400  | loss  0.00 | err rate  0.00%
# Minibatch  29500  | loss  0.00 | err rate  0.00%
# Minibatch  29600  | loss  0.00 | err rate  0.00%
# Minibatch  29700  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 38 | valid err rate:  1.46% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  29800  | loss  0.06 | err rate  0.78%
# Minibatch  29900  | loss  0.01 | err rate  0.00%
# Minibatch  30000  | loss  0.04 | err rate  0.78%
# Minibatch  30100  | loss  0.00 | err rate  0.00%
# Minibatch  30200  | loss  0.00 | err rate  0.00%
# Minibatch  30300  | loss  0.00 | err rate  0.00%
# Minibatch  30400  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 39 | valid err rate:  1.41% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  30500  | loss  0.00 | err rate  0.00%
# Minibatch  30600  | loss  0.01 | err rate  0.78%
# Minibatch  30700  | loss  0.01 | err rate  0.00%
# Minibatch  30800  | loss  0.01 | err rate  0.78%
# Minibatch  30900  | loss  0.00 | err rate  0.00%
# Minibatch  31000  | loss  0.00 | err rate  0.00%
# Minibatch  31100  | loss  0.00 | err rate  0.00%
# Minibatch  31200  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 40 | valid err rate:  1.45% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  31300  | loss  0.00 | err rate  0.00%
# Minibatch  31400  | loss  0.01 | err rate  0.78%
# Minibatch  31500  | loss  0.00 | err rate  0.00%
# Minibatch  31600  | loss  0.02 | err rate  0.78%
# Minibatch  31700  | loss  0.00 | err rate  0.00%
# Minibatch  31800  | loss  0.00 | err rate  0.00%
# Minibatch  31900  | loss  0.03 | err rate  0.78%
# Minibatch  32000  | loss  0.04 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 41 | valid err rate:  1.39% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  32100  | loss  0.02 | err rate  0.78%
# Minibatch  32200  | loss  0.00 | err rate  0.00%
# Minibatch  32300  | loss  0.00 | err rate  0.00%
# Minibatch  32400  | loss  0.00 | err rate  0.00%
# Minibatch  32500  | loss  0.00 | err rate  0.00%
# Minibatch  32600  | loss  0.00 | err rate  0.00%
# Minibatch  32700  | loss  0.00 | err rate  0.00%
# Minibatch  32800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 42 | valid err rate:  1.36% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  32900  | loss  0.00 | err rate  0.00%
# Minibatch  33000  | loss  0.00 | err rate  0.00%
# Minibatch  33100  | loss  0.00 | err rate  0.00%
# Minibatch  33200  | loss  0.01 | err rate  0.78%
# Minibatch  33300  | loss  0.00 | err rate  0.00%
# Minibatch  33400  | loss  0.00 | err rate  0.00%
# Minibatch  33500  | loss  0.00 | err rate  0.00%
# Minibatch  33600  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 43 | valid err rate:  1.26% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  33700  | loss  0.00 | err rate  0.00%
# Minibatch  33800  | loss  0.01 | err rate  0.00%
# Minibatch  33900  | loss  0.00 | err rate  0.00%
# Minibatch  34000  | loss  0.00 | err rate  0.00%
# Minibatch  34100  | loss  0.00 | err rate  0.00%
# Minibatch  34200  | loss  0.04 | err rate  2.34%
# Minibatch  34300  | loss  0.00 | err rate  0.00%
# Minibatch  34400  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 44 | valid err rate:  1.38% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  34500  | loss  0.08 | err rate  0.78%
# Minibatch  34600  | loss  0.04 | err rate  0.78%
# Minibatch  34700  | loss  0.00 | err rate  0.00%
# Minibatch  34800  | loss  0.00 | err rate  0.00%
# Minibatch  34900  | loss  0.00 | err rate  0.00%
# Minibatch  35000  | loss  0.00 | err rate  0.00%
# Minibatch  35100  | loss  0.05 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 45 | valid err rate:  1.33% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  35200  | loss  0.00 | err rate  0.00%
# Minibatch  35300  | loss  0.01 | err rate  0.78%
# Minibatch  35400  | loss  0.00 | err rate  0.00%
# Minibatch  35500  | loss  0.00 | err rate  0.00%
# Minibatch  35600  | loss  0.01 | err rate  0.78%
# Minibatch  35700  | loss  0.00 | err rate  0.00%
# Minibatch  35800  | loss  0.00 | err rate  0.00%
# Minibatch  35900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 46 | valid err rate:  1.34% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  36000  | loss  0.00 | err rate  0.00%
# Minibatch  36100  | loss  0.01 | err rate  0.78%
# Minibatch  36200  | loss  0.00 | err rate  0.00%
# Minibatch  36300  | loss  0.00 | err rate  0.00%
# Minibatch  36400  | loss  0.02 | err rate  0.78%
# Minibatch  36500  | loss  0.00 | err rate  0.00%
# Minibatch  36600  | loss  0.01 | err rate  0.78%
# Minibatch  36700  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 47 | valid err rate:  1.41% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  36800  | loss  0.00 | err rate  0.00%
# Minibatch  36900  | loss  0.00 | err rate  0.00%
# Minibatch  37000  | loss  0.00 | err rate  0.00%
# Minibatch  37100  | loss  0.00 | err rate  0.00%
# Minibatch  37200  | loss  0.00 | err rate  0.00%
# Minibatch  37300  | loss  0.02 | err rate  0.78%
# Minibatch  37400  | loss  0.00 | err rate  0.00%
# Minibatch  37500  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 48 | valid err rate:  1.33% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  37600  | loss  0.00 | err rate  0.00%
# Minibatch  37700  | loss  0.00 | err rate  0.00%
# Minibatch  37800  | loss  0.00 | err rate  0.00%
# Minibatch  37900  | loss  0.01 | err rate  0.78%
# Minibatch  38000  | loss  0.00 | err rate  0.00%
# Minibatch  38100  | loss  0.00 | err rate  0.00%
# Minibatch  38200  | loss  0.00 | err rate  0.00%
# Minibatch  38300  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 49 | valid err rate:  1.40% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  38400  | loss  0.06 | err rate  0.78%
# Minibatch  38500  | loss  0.01 | err rate  0.00%
# Minibatch  38600  | loss  0.00 | err rate  0.00%
# Minibatch  38700  | loss  0.02 | err rate  0.78%
# Minibatch  38800  | loss  0.02 | err rate  0.78%
# Minibatch  38900  | loss  0.00 | err rate  0.00%
# Minibatch  39000  | loss  0.01 | err rate  0.78%
# Minibatch  39100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 50 | valid err rate:  1.33% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  39200  | loss  0.00 | err rate  0.00%
# Minibatch  39300  | loss  0.00 | err rate  0.00%
# Minibatch  39400  | loss  0.01 | err rate  0.78%
# Minibatch  39500  | loss  0.00 | err rate  0.00%
# Minibatch  39600  | loss  0.02 | err rate  0.78%
# Minibatch  39700  | loss  0.00 | err rate  0.00%
# Minibatch  39800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 51 | valid err rate:  1.33% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  39900  | loss  0.00 | err rate  0.00%
# Minibatch  40000  | loss  0.00 | err rate  0.00%
# Minibatch  40100  | loss  0.00 | err rate  0.00%
# Minibatch  40200  | loss  0.00 | err rate  0.00%
# Minibatch  40300  | loss  0.02 | err rate  0.78%
# Minibatch  40400  | loss  0.00 | err rate  0.00%
# Minibatch  40500  | loss  0.00 | err rate  0.00%
# Minibatch  40600  | loss  0.02 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 52 | valid err rate:  1.33% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  40700  | loss  0.00 | err rate  0.00%
# Minibatch  40800  | loss  0.00 | err rate  0.00%
# Minibatch  40900  | loss  0.01 | err rate  0.00%
# Minibatch  41000  | loss  0.00 | err rate  0.00%
# Minibatch  41100  | loss  0.00 | err rate  0.00%
# Minibatch  41200  | loss  0.00 | err rate  0.00%
# Minibatch  41300  | loss  0.00 | err rate  0.00%
# Minibatch  41400  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 53 | valid err rate:  1.34% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  41500  | loss  0.00 | err rate  0.00%
# Minibatch  41600  | loss  0.00 | err rate  0.00%
# Minibatch  41700  | loss  0.00 | err rate  0.00%
# Minibatch  41800  | loss  0.01 | err rate  0.78%
# Minibatch  41900  | loss  0.00 | err rate  0.00%
# Minibatch  42000  | loss  0.00 | err rate  0.00%
# Minibatch  42100  | loss  0.00 | err rate  0.00%
# Minibatch  42200  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 54 | valid err rate:  1.41% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  42300  | loss  0.00 | err rate  0.00%
# Minibatch  42400  | loss  0.00 | err rate  0.00%
# Minibatch  42500  | loss  0.00 | err rate  0.00%
# Minibatch  42600  | loss  0.01 | err rate  0.78%
# Minibatch  42700  | loss  0.00 | err rate  0.00%
# Minibatch  42800  | loss  0.00 | err rate  0.00%
# Minibatch  42900  | loss  0.01 | err rate  0.00%
# Minibatch  43000  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 55 | valid err rate:  1.35% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  43100  | loss  0.00 | err rate  0.00%
# Minibatch  43200  | loss  0.00 | err rate  0.00%
# Minibatch  43300  | loss  0.00 | err rate  0.00%
# Minibatch  43400  | loss  0.00 | err rate  0.00%
# Minibatch  43500  | loss  0.01 | err rate  0.78%
# Minibatch  43600  | loss  0.00 | err rate  0.00%
# Minibatch  43700  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 56 | valid err rate:  1.33% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  43800  | loss  0.01 | err rate  0.00%
# Minibatch  43900  | loss  0.00 | err rate  0.00%
# Minibatch  44000  | loss  0.00 | err rate  0.00%
# Minibatch  44100  | loss  0.00 | err rate  0.00%
# Minibatch  44200  | loss  0.00 | err rate  0.00%
# Minibatch  44300  | loss  0.00 | err rate  0.00%
# Minibatch  44400  | loss  0.00 | err rate  0.00%
# Minibatch  44500  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 57 | valid err rate:  1.38% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  44600  | loss  0.00 | err rate  0.00%
# Minibatch  44700  | loss  0.01 | err rate  0.78%
# Minibatch  44800  | loss  0.00 | err rate  0.00%
# Minibatch  44900  | loss  0.00 | err rate  0.00%
# Minibatch  45000  | loss  0.00 | err rate  0.00%
# Minibatch  45100  | loss  0.00 | err rate  0.00%
# Minibatch  45200  | loss  0.05 | err rate  2.34%
# Minibatch  45300  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 58 | valid err rate:  1.35% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  45400  | loss  0.00 | err rate  0.00%
# Minibatch  45500  | loss  0.00 | err rate  0.00%
# Minibatch  45600  | loss  0.00 | err rate  0.00%
# Minibatch  45700  | loss  0.00 | err rate  0.00%
# Minibatch  45800  | loss  0.00 | err rate  0.00%
# Minibatch  45900  | loss  0.01 | err rate  0.00%
# Minibatch  46000  | loss  0.02 | err rate  0.78%
# Minibatch  46100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 59 | valid err rate:  1.27% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  46200  | loss  0.00 | err rate  0.00%
# Minibatch  46300  | loss  0.05 | err rate  0.78%
# Minibatch  46400  | loss  0.00 | err rate  0.00%
# Minibatch  46500  | loss  0.00 | err rate  0.00%
# Minibatch  46600  | loss  0.00 | err rate  0.00%
# Minibatch  46700  | loss  0.05 | err rate  1.56%
# Minibatch  46800  | loss  0.01 | err rate  0.00%
# Minibatch  46900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 60 | valid err rate:  1.36% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  47000  | loss  0.02 | err rate  0.78%
# Minibatch  47100  | loss  0.00 | err rate  0.00%
# Minibatch  47200  | loss  0.00 | err rate  0.00%
# Minibatch  47300  | loss  0.00 | err rate  0.00%
# Minibatch  47400  | loss  0.00 | err rate  0.00%
# Minibatch  47500  | loss  0.01 | err rate  0.78%
# Minibatch  47600  | loss  0.01 | err rate  0.00%
# Minibatch  47700  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 61 | valid err rate:  1.35% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  47800  | loss  0.00 | err rate  0.00%
# Minibatch  47900  | loss  0.01 | err rate  0.78%
# Minibatch  48000  | loss  0.00 | err rate  0.00%
# Minibatch  48100  | loss  0.01 | err rate  0.00%
# Minibatch  48200  | loss  0.01 | err rate  0.78%
# Minibatch  48300  | loss  0.00 | err rate  0.00%
# Minibatch  48400  | loss  0.03 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 62 | valid err rate:  1.30% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  48500  | loss  0.01 | err rate  0.78%
# Minibatch  48600  | loss  0.00 | err rate  0.00%
# Minibatch  48700  | loss  0.00 | err rate  0.00%
# Minibatch  48800  | loss  0.00 | err rate  0.00%
# Minibatch  48900  | loss  0.00 | err rate  0.00%
# Minibatch  49000  | loss  0.00 | err rate  0.00%
# Minibatch  49100  | loss  0.04 | err rate  0.78%
# Minibatch  49200  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 63 | valid err rate:  1.40% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  49300  | loss  0.00 | err rate  0.00%
# Minibatch  49400  | loss  0.00 | err rate  0.00%
# Minibatch  49500  | loss  0.00 | err rate  0.00%
# Minibatch  49600  | loss  0.00 | err rate  0.00%
# Minibatch  49700  | loss  0.01 | err rate  0.78%
# Minibatch  49800  | loss  0.00 | err rate  0.00%
# Minibatch  49900  | loss  0.00 | err rate  0.00%
# Minibatch  50000  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 64 | valid err rate:  1.33% | doing  65 epochs
# ----------------------------------------------------------
# Minibatch  50100  | loss  0.00 | err rate  0.00%
# Minibatch  50200  | loss  0.00 | err rate  0.00%
# Minibatch  50300  | loss  0.00 | err rate  0.00%
# Minibatch  50400  | loss  0.00 | err rate  0.00%
# Minibatch  50500  | loss  0.00 | err rate  0.00%
# Minibatch  50600  | loss  0.00 | err rate  0.00%
# Minibatch  50700  | loss  0.01 | err rate  0.78%
# Minibatch  50800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 65 | valid err rate:  1.38% | doing  65 epochs
# ----------------------------------------------------------
#
# Loading best params on validation set (epoch 43)
#
# Test error rate: 1.01%

# %% [markdown]
# # Problem 5: Batch Normalization [1p]
#
# *Covariate shift* is a phenomenon associated with training deep models. Simply put, weight changes in early layers cause major changes in distribution of inputs to later layers, making it difficult to train later layers.
#
# [Batch Normalization](https://arxiv.org/abs/1502.03167) addresses this problem by normalizing distributions of inputs to layers within mini-batches. It typically allows to train networks faster and/or with higher learning rates, lessens the importance
# of initialization and might eliminate the need for Dropout.
#
# Implement Batch Normalization and compare with regular training of MNIST models.
#
# Remember to use the batch statistics during model training and to use an average of training batch statistics during model evaluation. For details please consult the paper.

# %% [markdown]
# # Problem 6: Norm Constraints [1p bonus]
#
# Implement norm constraints, i.e. instead of weight decay, that tries to set
# all weights to small values, apply a limit on the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").
#
# Please consult the Dropout paper (http://arxiv.org/pdf/1207.0580.pdf) for details.

# %% [markdown]
# # Problem 6: Polyak Averaging [1p bonus]
#
# Implement Polyak averaging. For each parameter $\theta$
# keep a separate, exponentially decayed average of the past values
# $$
# \bar{\theta}_n = \alpha_p\bar{\theta}_{n-1} + (1-\alpha_p)\theta_n.
# $$
# Use that average when evaluating the model on the test set.
# Validate the approach by training a model on the MNIST dataset.

# %%
model = FeedforwardNet([
        AffineLayer(784,700),
        ReLULayer(),
        AffineLayer(700,500),
        ReLULayer(),
        AffineLayer(500,300),
        ReLULayer(),
        DropOutLayer(),
        AffineLayer(300,10),
        SoftMaxLayer()
        ])
model.train_mode()
# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        x = min(0.04, np.sqrt(6.) / np.sqrt( p.data.size()[0] + p.data.size()[1] ))
        p.data.uniform_(-x, x)
    elif p.name == 'b':
        p.data.zero_()
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# On lab computers you can set cuda=True !
SGD(model, mnist_loaders, alpha=0.1, cuda=True, no_dropout=False, poylak=True)

model.eval_mode()
print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  1.06 | err rate 27.34%
# Minibatch    200  | loss  0.46 | err rate 12.50%
# Minibatch    300  | loss  0.25 | err rate  9.38%
# Minibatch    400  | loss  0.23 | err rate  8.59%
# Minibatch    500  | loss  0.21 | err rate  3.12%
# Minibatch    600  | loss  0.27 | err rate  7.81%
# Minibatch    700  | loss  0.28 | err rate  9.38%
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  4.92% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.31 | err rate  9.38%
# Minibatch    900  | loss  0.39 | err rate 10.16%
# Minibatch   1000  | loss  0.30 | err rate  8.59%
# Minibatch   1100  | loss  0.22 | err rate  6.25%
# Minibatch   1200  | loss  0.08 | err rate  1.56%
# Minibatch   1300  | loss  0.25 | err rate  6.25%
# Minibatch   1400  | loss  0.06 | err rate  1.56%
# Minibatch   1500  | loss  0.09 | err rate  0.78%
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  3.22% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.17 | err rate  3.91%
# Minibatch   1700  | loss  0.12 | err rate  1.56%
# Minibatch   1800  | loss  0.10 | err rate  3.12%
# Minibatch   1900  | loss  0.07 | err rate  2.34%
# Minibatch   2000  | loss  0.08 | err rate  1.56%
# Minibatch   2100  | loss  0.05 | err rate  1.56%
# Minibatch   2200  | loss  0.04 | err rate  0.78%
# Minibatch   2300  | loss  0.30 | err rate  5.47%
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  2.44% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.05 | err rate  2.34%
# Minibatch   2500  | loss  0.04 | err rate  0.78%
# Minibatch   2600  | loss  0.05 | err rate  0.78%
# Minibatch   2700  | loss  0.14 | err rate  2.34%
# Minibatch   2800  | loss  0.02 | err rate  0.00%
# Minibatch   2900  | loss  0.06 | err rate  2.34%
# Minibatch   3000  | loss  0.05 | err rate  1.56%
# Minibatch   3100  | loss  0.07 | err rate  2.34%
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  2.49% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.08 | err rate  2.34%
# Minibatch   3300  | loss  0.07 | err rate  2.34%
# Minibatch   3400  | loss  0.05 | err rate  2.34%
# Minibatch   3500  | loss  0.09 | err rate  3.12%
# Minibatch   3600  | loss  0.15 | err rate  3.12%
# Minibatch   3700  | loss  0.08 | err rate  3.12%
# Minibatch   3800  | loss  0.18 | err rate  3.12%
# Minibatch   3900  | loss  0.07 | err rate  2.34%
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  2.06% | doing   8 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.05 | err rate  0.78%
# Minibatch   4100  | loss  0.04 | err rate  2.34%
# Minibatch   4200  | loss  0.05 | err rate  1.56%
# Minibatch   4300  | loss  0.04 | err rate  1.56%
# Minibatch   4400  | loss  0.01 | err rate  0.00%
# Minibatch   4500  | loss  0.07 | err rate  2.34%
# Minibatch   4600  | loss  0.06 | err rate  0.78%
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  1.90% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.03 | err rate  0.78%
# Minibatch   4800  | loss  0.04 | err rate  1.56%
# Minibatch   4900  | loss  0.06 | err rate  1.56%
# Minibatch   5000  | loss  0.04 | err rate  0.78%
# Minibatch   5100  | loss  0.03 | err rate  1.56%
# Minibatch   5200  | loss  0.02 | err rate  0.78%
# Minibatch   5300  | loss  0.22 | err rate  3.91%
# Minibatch   5400  | loss  0.02 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  1.84% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.07 | err rate  3.12%
# Minibatch   5600  | loss  0.03 | err rate  1.56%
# Minibatch   5700  | loss  0.01 | err rate  0.00%
# Minibatch   5800  | loss  0.04 | err rate  0.78%
# Minibatch   5900  | loss  0.02 | err rate  0.00%
# Minibatch   6000  | loss  0.01 | err rate  0.00%
# Minibatch   6100  | loss  0.01 | err rate  0.00%
# Minibatch   6200  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  1.89% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.10 | err rate  1.56%
# Minibatch   6400  | loss  0.04 | err rate  0.78%
# Minibatch   6500  | loss  0.02 | err rate  0.78%
# Minibatch   6600  | loss  0.03 | err rate  0.78%
# Minibatch   6700  | loss  0.00 | err rate  0.00%
# Minibatch   6800  | loss  0.04 | err rate  0.78%
# Minibatch   6900  | loss  0.01 | err rate  0.78%
# Minibatch   7000  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  1.79% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   7100  | loss  0.03 | err rate  2.34%
# Minibatch   7200  | loss  0.05 | err rate  1.56%
# Minibatch   7300  | loss  0.04 | err rate  2.34%
# Minibatch   7400  | loss  0.03 | err rate  2.34%
# Minibatch   7500  | loss  0.01 | err rate  0.78%
# Minibatch   7600  | loss  0.00 | err rate  0.00%
# Minibatch   7700  | loss  0.07 | err rate  1.56%
# Minibatch   7800  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  1.76% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   7900  | loss  0.01 | err rate  0.00%
# Minibatch   8000  | loss  0.03 | err rate  0.78%
# Minibatch   8100  | loss  0.01 | err rate  0.00%
# Minibatch   8200  | loss  0.02 | err rate  0.78%
# Minibatch   8300  | loss  0.04 | err rate  0.78%
# Minibatch   8400  | loss  0.01 | err rate  0.00%
# Minibatch   8500  | loss  0.04 | err rate  1.56%
# Minibatch   8600  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  1.78% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   8700  | loss  0.04 | err rate  1.56%
# Minibatch   8800  | loss  0.03 | err rate  1.56%
# Minibatch   8900  | loss  0.02 | err rate  0.78%
# Minibatch   9000  | loss  0.01 | err rate  0.00%
# Minibatch   9100  | loss  0.01 | err rate  0.78%
# Minibatch   9200  | loss  0.00 | err rate  0.00%
# Minibatch   9300  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  1.59% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch   9400  | loss  0.00 | err rate  0.00%
# Minibatch   9500  | loss  0.05 | err rate  0.78%
# Minibatch   9600  | loss  0.04 | err rate  2.34%
# Minibatch   9700  | loss  0.01 | err rate  0.00%
# Minibatch   9800  | loss  0.02 | err rate  0.78%
# Minibatch   9900  | loss  0.04 | err rate  1.56%
# Minibatch  10000  | loss  0.01 | err rate  0.00%
# Minibatch  10100  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  1.64% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch  10200  | loss  0.02 | err rate  0.78%
# Minibatch  10300  | loss  0.01 | err rate  0.00%
# Minibatch  10400  | loss  0.01 | err rate  0.00%
# Minibatch  10500  | loss  0.04 | err rate  1.56%
# Minibatch  10600  | loss  0.02 | err rate  0.78%
# Minibatch  10700  | loss  0.03 | err rate  0.78%
# Minibatch  10800  | loss  0.04 | err rate  1.56%
# Minibatch  10900  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  1.61% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch  11000  | loss  0.00 | err rate  0.00%
# Minibatch  11100  | loss  0.00 | err rate  0.00%
# Minibatch  11200  | loss  0.00 | err rate  0.00%
# Minibatch  11300  | loss  0.03 | err rate  0.78%
# Minibatch  11400  | loss  0.03 | err rate  0.78%
# Minibatch  11500  | loss  0.00 | err rate  0.00%
# Minibatch  11600  | loss  0.02 | err rate  0.78%
# Minibatch  11700  | loss  0.03 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  1.59% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch  11800  | loss  0.03 | err rate  1.56%
# Minibatch  11900  | loss  0.03 | err rate  1.56%
# Minibatch  12000  | loss  0.03 | err rate  0.78%
# Minibatch  12100  | loss  0.03 | err rate  0.78%
# Minibatch  12200  | loss  0.06 | err rate  1.56%
# Minibatch  12300  | loss  0.00 | err rate  0.00%
# Minibatch  12400  | loss  0.02 | err rate  0.78%
# Minibatch  12500  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  1.58% | doing  25 epochs
# ----------------------------------------------------------
# Minibatch  12600  | loss  0.00 | err rate  0.00%
# Minibatch  12700  | loss  0.01 | err rate  0.78%
# Minibatch  12800  | loss  0.09 | err rate  2.34%
# Minibatch  12900  | loss  0.00 | err rate  0.00%
# Minibatch  13000  | loss  0.01 | err rate  0.00%
# Minibatch  13100  | loss  0.02 | err rate  1.56%
# Minibatch  13200  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  1.56% | doing  26 epochs
# ----------------------------------------------------------
# Minibatch  13300  | loss  0.05 | err rate  0.78%
# Minibatch  13400  | loss  0.00 | err rate  0.00%
# Minibatch  13500  | loss  0.00 | err rate  0.00%
# Minibatch  13600  | loss  0.00 | err rate  0.00%
# Minibatch  13700  | loss  0.00 | err rate  0.00%
# Minibatch  13800  | loss  0.03 | err rate  0.78%
# Minibatch  13900  | loss  0.00 | err rate  0.00%
# Minibatch  14000  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  1.53% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  14100  | loss  0.08 | err rate  1.56%
# Minibatch  14200  | loss  0.00 | err rate  0.00%
# Minibatch  14300  | loss  0.00 | err rate  0.00%
# Minibatch  14400  | loss  0.01 | err rate  0.00%
# Minibatch  14500  | loss  0.00 | err rate  0.00%
# Minibatch  14600  | loss  0.00 | err rate  0.00%
# Minibatch  14700  | loss  0.02 | err rate  1.56%
# Minibatch  14800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  1.54% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  14900  | loss  0.00 | err rate  0.00%
# Minibatch  15000  | loss  0.00 | err rate  0.00%
# Minibatch  15100  | loss  0.00 | err rate  0.00%
# Minibatch  15200  | loss  0.01 | err rate  0.00%
# Minibatch  15300  | loss  0.08 | err rate  2.34%
# Minibatch  15400  | loss  0.01 | err rate  0.00%
# Minibatch  15500  | loss  0.02 | err rate  0.78%
# Minibatch  15600  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  1.54% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  15700  | loss  0.02 | err rate  0.78%
# Minibatch  15800  | loss  0.01 | err rate  0.78%
# Minibatch  15900  | loss  0.00 | err rate  0.00%
# Minibatch  16000  | loss  0.01 | err rate  0.00%
# Minibatch  16100  | loss  0.01 | err rate  0.78%
# Minibatch  16200  | loss  0.06 | err rate  0.78%
# Minibatch  16300  | loss  0.01 | err rate  0.78%
# Minibatch  16400  | loss  0.02 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 21 | valid err rate:  1.55% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  16500  | loss  0.01 | err rate  0.00%
# Minibatch  16600  | loss  0.04 | err rate  1.56%
# Minibatch  16700  | loss  0.01 | err rate  0.78%
# Minibatch  16800  | loss  0.01 | err rate  0.00%
# Minibatch  16900  | loss  0.00 | err rate  0.00%
# Minibatch  17000  | loss  0.01 | err rate  0.00%
# Minibatch  17100  | loss  0.02 | err rate  0.78%
# Minibatch  17200  | loss  0.03 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 22 | valid err rate:  1.56% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  17300  | loss  0.00 | err rate  0.00%
# Minibatch  17400  | loss  0.00 | err rate  0.00%
# Minibatch  17500  | loss  0.00 | err rate  0.00%
# Minibatch  17600  | loss  0.02 | err rate  0.78%
# Minibatch  17700  | loss  0.03 | err rate  0.78%
# Minibatch  17800  | loss  0.03 | err rate  1.56%
# Minibatch  17900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 23 | valid err rate:  1.60% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  18000  | loss  0.00 | err rate  0.00%
# Minibatch  18100  | loss  0.01 | err rate  0.00%
# Minibatch  18200  | loss  0.05 | err rate  2.34%
# Minibatch  18300  | loss  0.01 | err rate  0.78%
# Minibatch  18400  | loss  0.00 | err rate  0.00%
# Minibatch  18500  | loss  0.00 | err rate  0.00%
# Minibatch  18600  | loss  0.00 | err rate  0.00%
# Minibatch  18700  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 24 | valid err rate:  1.50% | doing  37 epochs
# ----------------------------------------------------------
# Minibatch  18800  | loss  0.00 | err rate  0.00%
# Minibatch  18900  | loss  0.02 | err rate  0.78%
# Minibatch  19000  | loss  0.07 | err rate  0.78%
# Minibatch  19100  | loss  0.00 | err rate  0.00%
# Minibatch  19200  | loss  0.01 | err rate  0.00%
# Minibatch  19300  | loss  0.07 | err rate  2.34%
# Minibatch  19400  | loss  0.02 | err rate  1.56%
# Minibatch  19500  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 25 | valid err rate:  1.50% | doing  37 epochs
# ----------------------------------------------------------
# Minibatch  19600  | loss  0.00 | err rate  0.00%
# Minibatch  19700  | loss  0.00 | err rate  0.00%
# Minibatch  19800  | loss  0.00 | err rate  0.00%
# Minibatch  19900  | loss  0.01 | err rate  0.00%
# Minibatch  20000  | loss  0.00 | err rate  0.00%
# Minibatch  20100  | loss  0.01 | err rate  0.78%
# Minibatch  20200  | loss  0.01 | err rate  0.00%
# Minibatch  20300  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 26 | valid err rate:  1.42% | doing  40 epochs
# ----------------------------------------------------------
# Minibatch  20400  | loss  0.01 | err rate  0.78%
# Minibatch  20500  | loss  0.01 | err rate  0.78%
# Minibatch  20600  | loss  0.00 | err rate  0.00%
# Minibatch  20700  | loss  0.00 | err rate  0.00%
# Minibatch  20800  | loss  0.00 | err rate  0.00%
# Minibatch  20900  | loss  0.00 | err rate  0.00%
# Minibatch  21000  | loss  0.00 | err rate  0.00%
# Minibatch  21100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 27 | valid err rate:  1.46% | doing  40 epochs
# ----------------------------------------------------------
# Minibatch  21200  | loss  0.03 | err rate  0.78%
# Minibatch  21300  | loss  0.00 | err rate  0.00%
# Minibatch  21400  | loss  0.01 | err rate  0.00%
# Minibatch  21500  | loss  0.00 | err rate  0.00%
# Minibatch  21600  | loss  0.01 | err rate  0.00%
# Minibatch  21700  | loss  0.01 | err rate  0.00%
# Minibatch  21800  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 28 | valid err rate:  1.52% | doing  40 epochs
# ----------------------------------------------------------
# Minibatch  21900  | loss  0.00 | err rate  0.00%
# Minibatch  22000  | loss  0.02 | err rate  0.78%
# Minibatch  22100  | loss  0.03 | err rate  0.78%
# Minibatch  22200  | loss  0.01 | err rate  0.00%
# Minibatch  22300  | loss  0.06 | err rate  1.56%
# Minibatch  22400  | loss  0.01 | err rate  0.00%
# Minibatch  22500  | loss  0.01 | err rate  0.78%
# Minibatch  22600  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 29 | valid err rate:  1.39% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  22700  | loss  0.00 | err rate  0.00%
# Minibatch  22800  | loss  0.00 | err rate  0.00%
# Minibatch  22900  | loss  0.00 | err rate  0.00%
# Minibatch  23000  | loss  0.06 | err rate  1.56%
# Minibatch  23100  | loss  0.02 | err rate  0.78%
# Minibatch  23200  | loss  0.01 | err rate  0.00%
# Minibatch  23300  | loss  0.01 | err rate  0.00%
# Minibatch  23400  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 30 | valid err rate:  1.42% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  23500  | loss  0.00 | err rate  0.00%
# Minibatch  23600  | loss  0.00 | err rate  0.00%
# Minibatch  23700  | loss  0.00 | err rate  0.00%
# Minibatch  23800  | loss  0.01 | err rate  0.78%
# Minibatch  23900  | loss  0.00 | err rate  0.00%
# Minibatch  24000  | loss  0.01 | err rate  0.00%
# Minibatch  24100  | loss  0.02 | err rate  0.78%
# Minibatch  24200  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 31 | valid err rate:  1.50% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  24300  | loss  0.01 | err rate  0.00%
# Minibatch  24400  | loss  0.00 | err rate  0.00%
# Minibatch  24500  | loss  0.00 | err rate  0.00%
# Minibatch  24600  | loss  0.00 | err rate  0.00%
# Minibatch  24700  | loss  0.05 | err rate  1.56%
# Minibatch  24800  | loss  0.06 | err rate  1.56%
# Minibatch  24900  | loss  0.00 | err rate  0.00%
# Minibatch  25000  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 32 | valid err rate:  1.53% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  25100  | loss  0.02 | err rate  1.56%
# Minibatch  25200  | loss  0.01 | err rate  0.78%
# Minibatch  25300  | loss  0.01 | err rate  0.00%
# Minibatch  25400  | loss  0.00 | err rate  0.00%
# Minibatch  25500  | loss  0.00 | err rate  0.00%
# Minibatch  25600  | loss  0.00 | err rate  0.00%
# Minibatch  25700  | loss  0.01 | err rate  0.00%
# Minibatch  25800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 33 | valid err rate:  1.38% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  25900  | loss  0.00 | err rate  0.00%
# Minibatch  26000  | loss  0.00 | err rate  0.00%
# Minibatch  26100  | loss  0.00 | err rate  0.00%
# Minibatch  26200  | loss  0.00 | err rate  0.00%
# Minibatch  26300  | loss  0.00 | err rate  0.00%
# Minibatch  26400  | loss  0.02 | err rate  0.78%
# Minibatch  26500  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 34 | valid err rate:  1.43% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  26600  | loss  0.04 | err rate  1.56%
# Minibatch  26700  | loss  0.02 | err rate  0.78%
# Minibatch  26800  | loss  0.02 | err rate  0.78%
# Minibatch  26900  | loss  0.00 | err rate  0.00%
# Minibatch  27000  | loss  0.00 | err rate  0.00%
# Minibatch  27100  | loss  0.00 | err rate  0.00%
# Minibatch  27200  | loss  0.00 | err rate  0.00%
# Minibatch  27300  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 35 | valid err rate:  1.49% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  27400  | loss  0.03 | err rate  0.78%
# Minibatch  27500  | loss  0.00 | err rate  0.00%
# Minibatch  27600  | loss  0.01 | err rate  0.00%
# Minibatch  27700  | loss  0.00 | err rate  0.00%
# Minibatch  27800  | loss  0.02 | err rate  0.78%
# Minibatch  27900  | loss  0.00 | err rate  0.00%
# Minibatch  28000  | loss  0.03 | err rate  0.78%
# Minibatch  28100  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 36 | valid err rate:  1.42% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  28200  | loss  0.00 | err rate  0.00%
# Minibatch  28300  | loss  0.01 | err rate  0.00%
# Minibatch  28400  | loss  0.01 | err rate  0.00%
# Minibatch  28500  | loss  0.02 | err rate  1.56%
# Minibatch  28600  | loss  0.00 | err rate  0.00%
# Minibatch  28700  | loss  0.00 | err rate  0.00%
# Minibatch  28800  | loss  0.00 | err rate  0.00%
# Minibatch  28900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 37 | valid err rate:  1.33% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  29000  | loss  0.00 | err rate  0.00%
# Minibatch  29100  | loss  0.00 | err rate  0.00%
# Minibatch  29200  | loss  0.00 | err rate  0.00%
# Minibatch  29300  | loss  0.00 | err rate  0.00%
# Minibatch  29400  | loss  0.00 | err rate  0.00%
# Minibatch  29500  | loss  0.00 | err rate  0.00%
# Minibatch  29600  | loss  0.00 | err rate  0.00%
# Minibatch  29700  | loss  0.01 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 38 | valid err rate:  1.43% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  29800  | loss  0.00 | err rate  0.00%
# Minibatch  29900  | loss  0.00 | err rate  0.00%
# Minibatch  30000  | loss  0.01 | err rate  0.78%
# Minibatch  30100  | loss  0.01 | err rate  0.00%
# Minibatch  30200  | loss  0.00 | err rate  0.00%
# Minibatch  30300  | loss  0.00 | err rate  0.00%
# Minibatch  30400  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 39 | valid err rate:  1.41% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  30500  | loss  0.01 | err rate  0.00%
# Minibatch  30600  | loss  0.02 | err rate  0.78%
# Minibatch  30700  | loss  0.00 | err rate  0.00%
# Minibatch  30800  | loss  0.00 | err rate  0.00%
# Minibatch  30900  | loss  0.00 | err rate  0.00%
# Minibatch  31000  | loss  0.04 | err rate  0.78%
# Minibatch  31100  | loss  0.01 | err rate  0.78%
# Minibatch  31200  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 40 | valid err rate:  1.41% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  31300  | loss  0.01 | err rate  0.78%
# Minibatch  31400  | loss  0.01 | err rate  0.00%
# Minibatch  31500  | loss  0.01 | err rate  0.78%
# Minibatch  31600  | loss  0.01 | err rate  0.78%
# Minibatch  31700  | loss  0.01 | err rate  0.78%
# Minibatch  31800  | loss  0.00 | err rate  0.00%
# Minibatch  31900  | loss  0.00 | err rate  0.00%
# Minibatch  32000  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 41 | valid err rate:  1.49% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  32100  | loss  0.02 | err rate  0.78%
# Minibatch  32200  | loss  0.00 | err rate  0.00%
# Minibatch  32300  | loss  0.01 | err rate  0.00%
# Minibatch  32400  | loss  0.03 | err rate  0.78%
# Minibatch  32500  | loss  0.01 | err rate  0.78%
# Minibatch  32600  | loss  0.01 | err rate  0.78%
# Minibatch  32700  | loss  0.00 | err rate  0.00%
# Minibatch  32800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 42 | valid err rate:  1.40% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  32900  | loss  0.00 | err rate  0.00%
# Minibatch  33000  | loss  0.00 | err rate  0.00%
# Minibatch  33100  | loss  0.00 | err rate  0.00%
# Minibatch  33200  | loss  0.01 | err rate  0.00%
# Minibatch  33300  | loss  0.02 | err rate  1.56%
# Minibatch  33400  | loss  0.00 | err rate  0.00%
# Minibatch  33500  | loss  0.00 | err rate  0.00%
# Minibatch  33600  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 43 | valid err rate:  1.38% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  33700  | loss  0.04 | err rate  0.78%
# Minibatch  33800  | loss  0.03 | err rate  1.56%
# Minibatch  33900  | loss  0.00 | err rate  0.00%
# Minibatch  34000  | loss  0.01 | err rate  0.00%
# Minibatch  34100  | loss  0.01 | err rate  0.00%
# Minibatch  34200  | loss  0.00 | err rate  0.00%
# Minibatch  34300  | loss  0.00 | err rate  0.00%
# Minibatch  34400  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 44 | valid err rate:  1.34% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  34500  | loss  0.00 | err rate  0.00%
# Minibatch  34600  | loss  0.00 | err rate  0.00%
# Minibatch  34700  | loss  0.04 | err rate  0.78%
# Minibatch  34800  | loss  0.01 | err rate  0.78%
# Minibatch  34900  | loss  0.01 | err rate  0.00%
# Minibatch  35000  | loss  0.04 | err rate  0.78%
# Minibatch  35100  | loss  0.01 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 45 | valid err rate:  1.42% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  35200  | loss  0.01 | err rate  0.00%
# Minibatch  35300  | loss  0.00 | err rate  0.00%
# Minibatch  35400  | loss  0.01 | err rate  0.00%
# Minibatch  35500  | loss  0.00 | err rate  0.00%
# Minibatch  35600  | loss  0.00 | err rate  0.00%
# Minibatch  35700  | loss  0.00 | err rate  0.00%
# Minibatch  35800  | loss  0.00 | err rate  0.00%
# Minibatch  35900  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 46 | valid err rate:  1.36% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  36000  | loss  0.00 | err rate  0.00%
# Minibatch  36100  | loss  0.00 | err rate  0.00%
# Minibatch  36200  | loss  0.00 | err rate  0.00%
# Minibatch  36300  | loss  0.02 | err rate  0.78%
# Minibatch  36400  | loss  0.01 | err rate  0.00%
# Minibatch  36500  | loss  0.00 | err rate  0.00%
# Minibatch  36600  | loss  0.00 | err rate  0.00%
# Minibatch  36700  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 47 | valid err rate:  1.45% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  36800  | loss  0.13 | err rate  1.56%
# Minibatch  36900  | loss  0.00 | err rate  0.00%
# Minibatch  37000  | loss  0.01 | err rate  0.00%
# Minibatch  37100  | loss  0.00 | err rate  0.00%
# Minibatch  37200  | loss  0.00 | err rate  0.00%
# Minibatch  37300  | loss  0.00 | err rate  0.00%
# Minibatch  37400  | loss  0.00 | err rate  0.00%
# Minibatch  37500  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 48 | valid err rate:  1.43% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  37600  | loss  0.00 | err rate  0.00%
# Minibatch  37700  | loss  0.00 | err rate  0.00%
# Minibatch  37800  | loss  0.05 | err rate  0.78%
# Minibatch  37900  | loss  0.02 | err rate  0.78%
# Minibatch  38000  | loss  0.02 | err rate  0.78%
# Minibatch  38100  | loss  0.00 | err rate  0.00%
# Minibatch  38200  | loss  0.00 | err rate  0.00%
# Minibatch  38300  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 49 | valid err rate:  1.44% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  38400  | loss  0.02 | err rate  0.78%
# Minibatch  38500  | loss  0.01 | err rate  0.00%
# Minibatch  38600  | loss  0.00 | err rate  0.00%
# Minibatch  38700  | loss  0.00 | err rate  0.00%
# Minibatch  38800  | loss  0.01 | err rate  0.78%
# Minibatch  38900  | loss  0.00 | err rate  0.00%
# Minibatch  39000  | loss  0.01 | err rate  0.00%
# Minibatch  39100  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 50 | valid err rate:  1.44% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  39200  | loss  0.01 | err rate  0.00%
# Minibatch  39300  | loss  0.01 | err rate  0.00%
# Minibatch  39400  | loss  0.00 | err rate  0.00%
# Minibatch  39500  | loss  0.00 | err rate  0.00%
# Minibatch  39600  | loss  0.00 | err rate  0.00%
# Minibatch  39700  | loss  0.00 | err rate  0.00%
# Minibatch  39800  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 51 | valid err rate:  1.44% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  39900  | loss  0.00 | err rate  0.00%
# Minibatch  40000  | loss  0.00 | err rate  0.00%
# Minibatch  40100  | loss  0.00 | err rate  0.00%
# Minibatch  40200  | loss  0.00 | err rate  0.00%
# Minibatch  40300  | loss  0.00 | err rate  0.00%
# Minibatch  40400  | loss  0.00 | err rate  0.00%
# Minibatch  40500  | loss  0.00 | err rate  0.00%
# Minibatch  40600  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 52 | valid err rate:  1.41% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  40700  | loss  0.01 | err rate  0.78%
# Minibatch  40800  | loss  0.00 | err rate  0.00%
# Minibatch  40900  | loss  0.00 | err rate  0.00%
# Minibatch  41000  | loss  0.00 | err rate  0.00%
# Minibatch  41100  | loss  0.00 | err rate  0.00%
# Minibatch  41200  | loss  0.00 | err rate  0.00%
# Minibatch  41300  | loss  0.00 | err rate  0.00%
# Minibatch  41400  | loss  0.03 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 53 | valid err rate:  1.40% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  41500  | loss  0.00 | err rate  0.00%
# Minibatch  41600  | loss  0.01 | err rate  0.00%
# Minibatch  41700  | loss  0.00 | err rate  0.00%
# Minibatch  41800  | loss  0.00 | err rate  0.00%
# Minibatch  41900  | loss  0.02 | err rate  0.78%
# Minibatch  42000  | loss  0.00 | err rate  0.00%
# Minibatch  42100  | loss  0.00 | err rate  0.00%
# Minibatch  42200  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 54 | valid err rate:  1.44% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  42300  | loss  0.00 | err rate  0.00%
# Minibatch  42400  | loss  0.00 | err rate  0.00%
# Minibatch  42500  | loss  0.01 | err rate  0.78%
# Minibatch  42600  | loss  0.01 | err rate  0.78%
# Minibatch  42700  | loss  0.00 | err rate  0.00%
# Minibatch  42800  | loss  0.00 | err rate  0.00%
# Minibatch  42900  | loss  0.00 | err rate  0.00%
# Minibatch  43000  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 55 | valid err rate:  1.40% | doing  56 epochs
# ----------------------------------------------------------
# Minibatch  43100  | loss  0.01 | err rate  0.78%
# Minibatch  43200  | loss  0.00 | err rate  0.00%
# Minibatch  43300  | loss  0.02 | err rate  0.78%
# Minibatch  43400  | loss  0.00 | err rate  0.00%
# Minibatch  43500  | loss  0.01 | err rate  0.78%
# Minibatch  43600  | loss  0.00 | err rate  0.00%
# Minibatch  43700  | loss  0.00 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 56 | valid err rate:  1.40% | doing  56 epochs
# ----------------------------------------------------------
# Test error rate: 1.11%

# %% [markdown]
# # Problem 7: Convolutional Network [2p bonus]
#
# Use convolutional and max-pooling layers (`torch.nn.functional.conv2d`, `torch.nn.functional.max_pool2d`) and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 8: Hyperparameter tuner [1p bonus]
#
# Implement a hyper-parameter tuner able to optimize the learing rate schedule, number of neurons and similar hyperparameters. For start, use random search (please see http://jmlr.csail.mit.edu/papers/volume13/bergstra12a/bergstra12a.pdf and especially Fig 1. for intuitions on why random search is better than grid search). It may be a good idea to use a fixed maximum number of epochs (or training time) for each optimization trial to prevent selecting hyperparameters that yield slowly converging solutions. A good result will be a set of hyperparameters that reach on MNIST solutions with test errors less than $1.3\%$ in no more than 50 epochs.
